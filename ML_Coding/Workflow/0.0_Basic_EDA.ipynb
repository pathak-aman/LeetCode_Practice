# %%
import pandas as pd

# %%
df = pd.read_csv("../data/covid_toy.csv")

# %%
def get_data_summary(df):
    """
    Generates a structured overview of the dataset, including:
    - Data type of each column
    - Number and percentage of missing values
    - Number and percentage of unique values
    - Most frequent value (mode)
    - Summary statistics (for numerical features)
    - First few records (to inspect sample values)
    """
    # Get column-wise metadata
    missing_vals = df.isna().sum()
    unique_vals = df.nunique()
    mode_vals = df.mode().iloc[0]
    
    summary_df = pd.DataFrame({
        "Data Type": df.dtypes,
        "# Records": df.shape[0],
        "# Missing": missing_vals,
        "% Missing": (missing_vals / df.shape[0]) * 100,
        "# Unique": unique_vals,
        "% Unique": (unique_vals / df.shape[0]) * 100,
        "Most Frequent Value": mode_vals
    })
    
    # Function to compute numerical statistics
    def get_numeric_summary(df):
        return df.select_dtypes(include="number").agg(["min", "max", "mean", "median", "std"]).T
    
    # Merge numerical statistics only for numeric columns
    num_summary = get_numeric_summary(df)
    summary_df = summary_df.merge(num_summary, left_index=True, right_index=True, how="left")
    
    # Append first few records to inspect data values
    preview = df.head(3).T  # Transpose for better readability
    summary_df = pd.concat([summary_df, preview], axis=1)
    
    return summary_df

# Display with color formatting
display(get_data_summary(df).style.background_gradient(subset=["# Unique", "std", "median", "mean", "max", "min", "% Missing"], cmap="Oranges"))
# Out:
# <style type="text/css">
# #T_20aaf_row0_col3, #T_20aaf_row0_col7, #T_20aaf_row0_col8, #T_20aaf_row0_col9, #T_20aaf_row0_col10, #T_20aaf_row1_col3, #T_20aaf_row1_col4, #T_20aaf_row2_col11, #T_20aaf_row3_col3, #T_20aaf_row3_col4, #T_20aaf_row4_col3, #T_20aaf_row5_col3, #T_20aaf_row5_col4 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_20aaf_row0_col4, #T_20aaf_row0_col11, #T_20aaf_row2_col3, #T_20aaf_row2_col7, #T_20aaf_row2_col8, #T_20aaf_row2_col9, #T_20aaf_row2_col10 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_20aaf_row1_col7, #T_20aaf_row1_col8, #T_20aaf_row1_col9, #T_20aaf_row1_col10, #T_20aaf_row1_col11, #T_20aaf_row3_col7, #T_20aaf_row3_col8, #T_20aaf_row3_col9, #T_20aaf_row3_col10, #T_20aaf_row3_col11, #T_20aaf_row4_col7, #T_20aaf_row4_col8, #T_20aaf_row4_col9, #T_20aaf_row4_col10, #T_20aaf_row4_col11, #T_20aaf_row5_col7, #T_20aaf_row5_col8, #T_20aaf_row5_col9, #T_20aaf_row5_col10, #T_20aaf_row5_col11 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_20aaf_row2_col4 {
#   background-color: #feead5;
#   color: #000000;
# }
# #T_20aaf_row4_col4 {
#   background-color: #fff1e3;
#   color: #000000;
# }
# </style>
# <table id="T_20aaf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20aaf_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_20aaf_level0_col1" class="col_heading level0 col1" ># Records</th>
#       <th id="T_20aaf_level0_col2" class="col_heading level0 col2" ># Missing</th>
#       <th id="T_20aaf_level0_col3" class="col_heading level0 col3" >% Missing</th>
#       <th id="T_20aaf_level0_col4" class="col_heading level0 col4" ># Unique</th>
#       <th id="T_20aaf_level0_col5" class="col_heading level0 col5" >% Unique</th>
#       <th id="T_20aaf_level0_col6" class="col_heading level0 col6" >Most Frequent Value</th>
#       <th id="T_20aaf_level0_col7" class="col_heading level0 col7" >min</th>
#       <th id="T_20aaf_level0_col8" class="col_heading level0 col8" >max</th>
#       <th id="T_20aaf_level0_col9" class="col_heading level0 col9" >mean</th>
#       <th id="T_20aaf_level0_col10" class="col_heading level0 col10" >median</th>
#       <th id="T_20aaf_level0_col11" class="col_heading level0 col11" >std</th>
#       <th id="T_20aaf_level0_col12" class="col_heading level0 col12" >0</th>
#       <th id="T_20aaf_level0_col13" class="col_heading level0 col13" >1</th>
#       <th id="T_20aaf_level0_col14" class="col_heading level0 col14" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20aaf_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_20aaf_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_20aaf_row0_col1" class="data row0 col1" >100</td>
#       <td id="T_20aaf_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_20aaf_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_20aaf_row0_col4" class="data row0 col4" >55</td>
#       <td id="T_20aaf_row0_col5" class="data row0 col5" >55.000000</td>
#       <td id="T_20aaf_row0_col6" class="data row0 col6" >19</td>
#       <td id="T_20aaf_row0_col7" class="data row0 col7" >5.000000</td>
#       <td id="T_20aaf_row0_col8" class="data row0 col8" >84.000000</td>
#       <td id="T_20aaf_row0_col9" class="data row0 col9" >44.220000</td>
#       <td id="T_20aaf_row0_col10" class="data row0 col10" >45.000000</td>
#       <td id="T_20aaf_row0_col11" class="data row0 col11" >24.878931</td>
#       <td id="T_20aaf_row0_col12" class="data row0 col12" >60</td>
#       <td id="T_20aaf_row0_col13" class="data row0 col13" >27</td>
#       <td id="T_20aaf_row0_col14" class="data row0 col14" >42</td>
#     </tr>
#     <tr>
#       <th id="T_20aaf_level0_row1" class="row_heading level0 row1" >gender</th>
#       <td id="T_20aaf_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_20aaf_row1_col1" class="data row1 col1" >100</td>
#       <td id="T_20aaf_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_20aaf_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_20aaf_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_20aaf_row1_col5" class="data row1 col5" >2.000000</td>
#       <td id="T_20aaf_row1_col6" class="data row1 col6" >Female</td>
#       <td id="T_20aaf_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_20aaf_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_20aaf_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_20aaf_row1_col10" class="data row1 col10" >nan</td>
#       <td id="T_20aaf_row1_col11" class="data row1 col11" >nan</td>
#       <td id="T_20aaf_row1_col12" class="data row1 col12" >Male</td>
#       <td id="T_20aaf_row1_col13" class="data row1 col13" >Male</td>
#       <td id="T_20aaf_row1_col14" class="data row1 col14" >Male</td>
#     </tr>
#     <tr>
#       <th id="T_20aaf_level0_row2" class="row_heading level0 row2" >fever</th>
#       <td id="T_20aaf_row2_col0" class="data row2 col0" >float64</td>
#       <td id="T_20aaf_row2_col1" class="data row2 col1" >100</td>
#       <td id="T_20aaf_row2_col2" class="data row2 col2" >10</td>
#       <td id="T_20aaf_row2_col3" class="data row2 col3" >10.000000</td>
#       <td id="T_20aaf_row2_col4" class="data row2 col4" >7</td>
#       <td id="T_20aaf_row2_col5" class="data row2 col5" >7.000000</td>
#       <td id="T_20aaf_row2_col6" class="data row2 col6" >98.000000</td>
#       <td id="T_20aaf_row2_col7" class="data row2 col7" >98.000000</td>
#       <td id="T_20aaf_row2_col8" class="data row2 col8" >104.000000</td>
#       <td id="T_20aaf_row2_col9" class="data row2 col9" >100.844444</td>
#       <td id="T_20aaf_row2_col10" class="data row2 col10" >101.000000</td>
#       <td id="T_20aaf_row2_col11" class="data row2 col11" >2.054926</td>
#       <td id="T_20aaf_row2_col12" class="data row2 col12" >103.000000</td>
#       <td id="T_20aaf_row2_col13" class="data row2 col13" >100.000000</td>
#       <td id="T_20aaf_row2_col14" class="data row2 col14" >101.000000</td>
#     </tr>
#     <tr>
#       <th id="T_20aaf_level0_row3" class="row_heading level0 row3" >cough</th>
#       <td id="T_20aaf_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_20aaf_row3_col1" class="data row3 col1" >100</td>
#       <td id="T_20aaf_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_20aaf_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_20aaf_row3_col4" class="data row3 col4" >2</td>
#       <td id="T_20aaf_row3_col5" class="data row3 col5" >2.000000</td>
#       <td id="T_20aaf_row3_col6" class="data row3 col6" >Mild</td>
#       <td id="T_20aaf_row3_col7" class="data row3 col7" >nan</td>
#       <td id="T_20aaf_row3_col8" class="data row3 col8" >nan</td>
#       <td id="T_20aaf_row3_col9" class="data row3 col9" >nan</td>
#       <td id="T_20aaf_row3_col10" class="data row3 col10" >nan</td>
#       <td id="T_20aaf_row3_col11" class="data row3 col11" >nan</td>
#       <td id="T_20aaf_row3_col12" class="data row3 col12" >Mild</td>
#       <td id="T_20aaf_row3_col13" class="data row3 col13" >Mild</td>
#       <td id="T_20aaf_row3_col14" class="data row3 col14" >Mild</td>
#     </tr>
#     <tr>
#       <th id="T_20aaf_level0_row4" class="row_heading level0 row4" >city</th>
#       <td id="T_20aaf_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_20aaf_row4_col1" class="data row4 col1" >100</td>
#       <td id="T_20aaf_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_20aaf_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_20aaf_row4_col4" class="data row4 col4" >4</td>
#       <td id="T_20aaf_row4_col5" class="data row4 col5" >4.000000</td>
#       <td id="T_20aaf_row4_col6" class="data row4 col6" >Kolkata</td>
#       <td id="T_20aaf_row4_col7" class="data row4 col7" >nan</td>
#       <td id="T_20aaf_row4_col8" class="data row4 col8" >nan</td>
#       <td id="T_20aaf_row4_col9" class="data row4 col9" >nan</td>
#       <td id="T_20aaf_row4_col10" class="data row4 col10" >nan</td>
#       <td id="T_20aaf_row4_col11" class="data row4 col11" >nan</td>
#       <td id="T_20aaf_row4_col12" class="data row4 col12" >Kolkata</td>
#       <td id="T_20aaf_row4_col13" class="dat
